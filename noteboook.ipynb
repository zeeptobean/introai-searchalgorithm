# %% [markdown]
# #### Continuous

# %%
from swarmalgo.pso import *
from swarmalgo.abc import *
from swarmalgo.cuckoo_search import *
from swarmalgo.tlbo import *
from swarmalgo.firefly import *
from algo.simulated_annealing import *
from algo.differential_evolution import *
from algo.genetic import *
from util.define import *
import function.continuous_function as contfunc
from visual import *

# %load_ext autoreload
# %autoreload 2

# problem = contfunc.GriewankFunction(dimension=5, lower_bound=-10, upper_bound=10)
# problem = contfunc.StyblinskiTangFunction(dimension=2)
# problem = contfunc.RastriginFunction(dimension=100, lower_bound=-4, upper_bound=4)
# problem = contfunc.AckleyFunction(dimension=30)
problem = contfunc.RosenbrockFunction(dimension=10, lower_bound=-2, upper_bound=2)
# result = tlbo_continuous(problem)
# result = tlbo_continuous(problem)
# result = cuckoo_search_continuous(problem, population_size=100)
# result = simulated_annealing_continuous(problem, cooling_rate=0.98)

results: list[ContinuousResult] = []

results.append(differential_evolution_continuous(problem))
results.append(genetic_algorithm_continuous(problem))
# results.append(simulated_annealing_linear_continuous(problem))
results.append(tlbo_continuous(problem))
results.append(cuckoo_search_continuous(problem))
results.append(pso_continuous(problem))
results.append(abc_continuous(problem))
results.append(firefly_continuous(problem))

plot1 = visualize_convergence_multiple(results, dark_theme=True)
plot1.show()

# with open("result.dat", "wb") as f:
#     f.write(result.to_binary())

# print(f"algo = {result.algorithm}, problem = {result.problem}")
# print(f"best = {result.best_value} at x = {result.best_x} took {result.time:.4f} ms")

# %%
from visual import *
with open("result.dat", "rb") as f:
    result = ContinuousResult.from_binary(f.read())

    # ContinuousResultVisualizer(result).visualize_3d(dark_theme=True)
    ContinuousResultVisualizer(result).visualize_2d(dark_theme=True)
    # visualize_convergence(result, dark_theme=False)

# %% [markdown]
# #### Discrete

# %%
from algo.simulated_annealing import *
from algo.differential_evolution import *
from algo.genetic import *
from util.define import *
import function.discrete_function as discfunc
from visual import *

# %load_ext autoreload
# %autoreload 2

problem = discfunc.KnapsackFunction(
    weights=np.array([10, 20, 30, 40, 50, 60, 65, 68, 69, 70]),
    values=np.array([60, 100, 120, 240, 300, 600, 700, 800, 6000, 1]),
    capacity=200,
    dimension=10
)

# distance_matrix=np.array([
# [ 0, 48, 65, 68, 68],
# [10,  0, 10, 35, 20],
# [5, 0,  0, 40, 0],
# [65, 0, 0,  0, 80],
# [85, 100, 55, 0, 0]
# ])

# problem = discfunc.TSPFunction(distance_matrix=distance_matrix, dimension=5)

result = differential_evolution_discrete(problem)
result2 = genetic_algorithm_discrete(problem)
result3 = simulated_annealing_discrete(problem)

plot1 = visualize_convergence_multiple([result, result2, result3], dark_theme=False)
plot2 = visualize_knapsack(result, dark_theme=False)
plot3 = visualize_knapsack(result2, dark_theme=False)
plot4 = visualize_knapsack(result3, dark_theme=False)
plot5 = visualize_runtime_vs_best([result, result2, result3], dark_theme=False)

plot1.show()
plot2.show()
plot3.show()
plot4.show()
plot5.show()

# print(f"algo = {result.algorithm}, problem = {result.problem}")
# print(f"best = {result.best_value} at x = {result.best_x} took {result.time:.4f} ms")

# with open("result.dat", "wb") as f:
    # f.write(result.to_binary())

# %%
from visual import *

with open("result.dat", "rb") as f:
    result = DiscreteResult.from_binary(f.read())
    visualize_knapsack(result, dark_theme=True)

# %% [markdown]
# #### Path finding

# %%
from algo.graph_search import *
from function.graph_problem import *
from visual import *

# %load_ext autoreload

problem = GridWorldProblem.generate(seed=2)

# result = astar(problem)
result: list[SearchResult] = []
result.append(dfs(problem))
result.append(bfs(problem))
result.append(astar(problem, heuristic_name="euclidean"))
result.append(astar(problem, heuristic_name="manhattan"))

# visualize_grid_search_multiple(result, dark_theme=True)
visualize_grid_search_multiple(result, dark_theme=False)

visualize_grid_search(result[0], dark_theme=True)
