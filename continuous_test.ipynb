# %% [markdown]
# #### Installation

# %%
# %pip install numpy plotly nbformat matplotlib networkx scipy ipython

# %% [markdown]
# **Import all**

# %%
dark_theme=False        # Set to True for dark theme in visualizations, False for light theme

from swarmalgo.aco import *
from swarmalgo.pso import *
from swarmalgo.abc import *
from swarmalgo.cuckoo_search import *
from swarmalgo.tlbo import *
from swarmalgo.firefly import *
from algo.simulated_annealing import *
from algo.differential_evolution import *
from algo.genetic import *
from util.define import *
import function.continuous_function as contfunc
from visual import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Continuous function demo

# %% [markdown]
# #### Continuous function test: RastriginFunction(dimension=2), rng_seed = 42

# %%
problem = contfunc.RastriginFunction(dimension=2)

rng_seed = 42

results: list[ContinuousResult] = []

results.append(differential_evolution_continuous(problem, rng_seed=rng_seed))
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, rng_seed=rng_seed))
results.append(tlbo_continuous(problem, rng_seed=rng_seed))
results.append(cuckoo_search_continuous(problem, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))
acoresult = aco_continuous(problem, rng_seed=rng_seed)
results.append(acoresult)

# Visualize the optimization process of ACOR in 2d and 3d
plot1 = visualize_2d(acoresult, dark_theme=dark_theme)   
plot2 = visualize_3d(acoresult, dark_theme=dark_theme)

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# **Retune Simulated Annealing for better convergence**

# %%
results[2] = simulated_annealing_continuous(problem, temp=200, cooling_rate=0.99, step_bound=2.5, min_temp=1e-5, rng_seed=rng_seed)

plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# #### SphereFunction(dimension=2) and bound within [-5, 5]; rng_seed = 42

# %%
problem = contfunc.SphereFunction(dimension=2, lower_bound=-5, upper_bound=5)

rng_seed = 42

results: list[ContinuousResult] = []

difres = differential_evolution_continuous(problem, rng_seed=rng_seed)
results.append(difres)
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, temp=200, cooling_rate=0.99, step_bound=2.5, min_temp=1e-5, rng_seed=rng_seed))
results.append(tlbo_continuous(problem, rng_seed=rng_seed))
results.append(cuckoo_search_continuous(problem, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))

# Visualize the optimization process of Differential Evolution algorithm in 2d and 3d
plot1 = visualize_2d(difres, dark_theme=dark_theme, canvas_size=(11, 8))
plot2 = visualize_3d(difres, dark_theme=dark_theme)

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# #### MichalewiczFunction(dimension=2), rng_seed = 42

# %%
problem = contfunc.MichalewiczFunction(dimension=2)

rng_seed = 42

results: list[ContinuousResult] = []

results.append(differential_evolution_continuous(problem, rng_seed=rng_seed))
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, temp=300, cooling_rate=0.95, step_bound=0.5, min_temp=1e-3, rng_seed=rng_seed))
tlbores = tlbo_continuous(problem, rng_seed=rng_seed)
results.append(tlbores)
results.append(cuckoo_search_continuous(problem, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))

# Visualize the optimization process of TLBO algorithm in 2d and 3d
plot1 = visualize_2d(tlbores, dark_theme=dark_theme, canvas_size=(11, 8))
plot2 = visualize_3d(tlbores, dark_theme=dark_theme)

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# #### AckleyFunction(dimension=4); rng_seed = 150

# %%
problem = contfunc.AckleyFunction(dimension=4)
rng_seed = 150

results: list[ContinuousResult] = []

results.append(differential_evolution_continuous(problem, rng_seed=rng_seed))
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, rng_seed=rng_seed))
results.append(tlbo_continuous(problem, rng_seed=rng_seed))
results.append(cuckoo_search_continuous(problem, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# #### GriewankFunction(dimension=8); rng_seed = 150

# %%
problem = contfunc.GriewankFunction(dimension=8)
rng_seed = 150

results: list[ContinuousResult] = []

results.append(differential_evolution_continuous(problem, rng_seed=rng_seed))
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, rng_seed=rng_seed))
results.append(tlbo_continuous(problem, rng_seed=rng_seed))
results.append(cuckoo_search_continuous(problem, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# #### StyblinskiTangFunction(dimension=4), rng_seed = 150
# With parameters tuning

# %%
problem = contfunc.StyblinskiTangFunction(dimension=4)
rng_seed = 150

results: list[ContinuousResult] = []

results.append(differential_evolution_continuous(problem, rng_seed=rng_seed))
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, temp=300, cooling_rate=0.92, step_bound=0.8, min_temp=0.01, rng_seed=rng_seed))
tlbores = tlbo_continuous(problem, rng_seed=rng_seed)
results.append(tlbores)
results.append(cuckoo_search_continuous(problem, population_size=35, generation=150, discovery_rate=0.35, beta=1.75, alpha=0.035, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# #### RosenbrockFunction(dimension=5) with bounds [-8, 8], rng_seed = 150

# %% [markdown]
# **Limit bound as exploration explosion on large bounds (or even unbounds)**

# %%
problem = contfunc.RosenbrockFunction(dimension=5, lower_bound=-8, upper_bound=8)
rng_seed = 150

results: list[ContinuousResult] = []

results.append(differential_evolution_continuous(problem, rng_seed=rng_seed))
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, temp=300, cooling_rate=0.92, step_bound=0.8, min_temp=0.01, rng_seed=rng_seed))
tlbores = tlbo_continuous(problem, rng_seed=rng_seed)
results.append(tlbores)
results.append(cuckoo_search_continuous(problem, population_size=35, generation=150, discovery_rate=0.35, beta=1.75, alpha=0.035, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# #### MichalewiczFunction(dimension=10), rng_seed = 9966
# One of the hardest function

# %%
problem = contfunc.MichalewiczFunction(dimension=10)

rng_seed = 9966

results: list[ContinuousResult] = []

difres = differential_evolution_continuous(problem, rng_seed=rng_seed)
results.append(difres)
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, temp=200, cooling_rate=0.99, step_bound=2.5, min_temp=1e-5, rng_seed=rng_seed))
results.append(tlbo_continuous(problem, rng_seed=rng_seed))
results.append(cuckoo_search_continuous(problem, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed))
results.append(abc_continuous(problem, rng_seed=rng_seed))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, rng_seed=rng_seed))

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()

# %% [markdown]
# **Tuning to closely approaching min = -9.66015**

# %%
rng_seed = 9966
problem = contfunc.MichalewiczFunction(dimension=10)
results: list[ContinuousResult] = []

difres = differential_evolution_continuous(problem, crossover_rate=0.2, mutation_factor=0.875, population_size=50, rng_seed=rng_seed, generation=200)
results.append(difres)
results.append(genetic_algorithm_continuous(problem, rng_seed=rng_seed))
results.append(simulated_annealing_continuous(problem, temp=200, cooling_rate=0.99, step_bound=0.5, min_temp=1e-5, rng_seed=rng_seed))
results.append(tlbo_continuous(problem, rng_seed=rng_seed, generation=500))
results.append(cuckoo_search_continuous(problem, alpha=0.035, discovery_rate=0.35, generation=200, rng_seed=rng_seed))
results.append(pso_continuous(problem, rng_seed=rng_seed, generation=200))
results.append(abc_continuous(problem, rng_seed=rng_seed, generation=200))
results.append(aco_continuous(problem, rng_seed=rng_seed))
results.append(firefly_continuous(problem, gamma=0.15, alpha=0.25, rng_seed=rng_seed, generation=200))

# Global comparison
plot3 = visualize_convergence_multiple(results, dark_theme=dark_theme)
plot4 = visualize_runtime_vs_best(results, dark_theme=dark_theme)
plot3.show()
plot4.show()
